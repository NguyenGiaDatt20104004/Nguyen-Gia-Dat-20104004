# %% [markdown]
# <a href="https://colab.research.google.com/github/NguyenGiaDatt20104004/Nguyen-Gia-Dat-20104004/blob/main/AI_(15112022).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
'''PRE_TRAINED MODELS'''
# Out:
# 'PRE_TRAINED MODELS'

# %%
#MTCNN (Multi_tasks cascaded Convolutional Newral Networks)

# %%
pip install mtcnn
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 2.3 MB 4.1 MB/s
# ...

# %%
import matplotlib.pyplot as plt
from mtcnn import MTCNN

# %%
url = "bbb.jpg"
pixels = plt.imread(url)

# %%
detector = MTCNN()

# %%
faces = detector.detect_faces(pixels)
# Out:
# ...
# 1/1 [==============================] - 0s 159ms/step

# %%
x=0
for face in faces:
  print(face)
  x=x+1
print(x)
# Out:
# {'box': [305, 457, 125, 165], 'confidence': 0.9941749572753906, 'keypoints': {'left_eye': (336, 522), 'right_eye': (392, 519), 'nose': (365, 552), 'mouth_left': (340, 581), 'mouth_right': (387, 579)}}
# {'box': [680, 166, 123, 154], 'confidence': 0.9879845976829529, 'keypoints': {'left_eye': (712, 225), 'right_eye': (765, 222), 'nose': (737, 247), 'mouth_left': (717, 278), 'mouth_right': (761, 275)}}
# {'box': [843, 56, 129, 161], 'confidence': 0.8753239512443542, 'keypoints': {'left_eye': (875, 123), 'right_eye': (929, 120), 'nose': (900, 146), 'mouth_left': (881, 176), 'mouth_right': (924, 174)}}
# {'box': [81, 547, 118, 161], 'confidence': 0.7588627338409424, 'keypoints': {'left_eye': (114, 612), 'right_eye': (168, 606), 'nose': (144, 634), 'mouth_left': (122, 664), 'mouth_right': (170, 660)}}
# ...

# %%
import matplotlib.pyplot as plt
from mtcnn import MTCNN

# %%
url = "abc.jpg"
pixels = plt.imread(url)
detector = MTCNN()
faces = detector.detect_faces(pixels)
plt.imshow(pixels)

ax = plt.gca()
for face in faces:
  x, y, width, height = face['box']
  rect = plt.Rectangle((x,y), width, height, fill=False, color="red")
  ax.add_patch(rect)

  for key, value in face["keypoints"].items():
    dot = plt.Circle (value, radius=2, color="yellow")
    ax.add_patch(dot)
plt.show()
# Out:
# ...
# 4/4 [==============================] - 0s 38ms/step

# %%
#cắt hình ảnh ra thành từng mặt nhỏ
import matplotlib.pyplot as plt
from mtcnn import MTCNN
def draw_faces(filename,result_list):
  data = plt.imread(filename)
  for i in range(len(result_list)):
    x1,y1,width,height = result_list[i]["box"]
    x2,y2 = x1+width, y1+height
    plt.subplot(1, len(result_list), i+1)
    plt.axis("off")
    plt.imshow(data[y1:y2, x1:x2])
  plt.show()

filename = "KL (9).jpg"
pixels = plt.imread(filename)
detector = MTCNN()
faces = detector.detect_faces(pixels)

draw_faces(filename, faces)
# Out:
# ...
# 1/1 [==============================] - 0s 148ms/step
