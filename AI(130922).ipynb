# %% [markdown]
# <a href="https://colab.research.google.com/github/NguyenGiaDatt20104004/Nguyen-Gia-Dat-20104004/blob/main/AI(130922).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from openpyxl import Workbook
wb = Workbook()
sheet = wb.active
sheet["A1"] = "Nguyen Van A"
sheet["B1"] = "20104001"
sheet["A2"] = "Le Thi B"
sheet["B2"] = "20104002"
wb.save("test.xlsx")

# %%
import openpyxl
wb = openpyxl.load_workbook("test.xlsx")
sheet = wb.active
t1 = sheet["A1"]
t2 = sheet["B1"]
t3 = sheet.cell(row = 2, column = 1)
t4 = sheet.cell(row = 2, column = 2)
print(t1.value, t2.value)
print(t3.value, t4.value)
# Out:
# Nguyen Van A 20104001
# Le Thi B 20104002

# %%
import openpyxl
wb = openpyxl.Workbook()
sheet = wb.active
c1 = sheet.cell(row = 1, column = 1)
c1.value = "Dang Tri Dung"
c2 = sheet.cell(row = 1, column = 2)
c2.value = "Trinh Duc Cuong"
c3 = sheet["A2"]
c3.value = "Ulsan"
c4 = sheet["B2"]
c4.value = "Genovoa"
wb.save("Book1.xlsx")

# %%
import openpyxl
wb = openpyxl.Workbook()
sheet = wb.active
wb.create_sheet(index = 1, title = "CDT")
wb.save("Book2.xlsx")

# %%
import openpyxl
url = "Book1.xlsx"
wb = openpyxl.load_workbook(url)
sheet = wb.active
print(sheet.max_row)
# Out:
# 2

# %%
import openpyxl
url = "Book1.xlsx"
wb = openpyxl.load_workbook(url)
sheet = wb.active
cell = sheet.cell(row = 1, column = 1)
print(cell.value)
# Out:
# Dang Tri Dung

# %%
import openpyxl
url = "Book1.xlsx"
wb = openpyxl.load_workbook(url)
sheet = wb.active
print(sheet.max_column)
# Out:
# 2

# %%
import openpyxl
url = "Book1.xlsx"
wb = openpyxl.load_workbook(url)
sheet = wb.active
col = sheet.max_column
for i in range(1, col + 1):
  cell = sheet.cell(row = 1, column = i)
  print(cell.value)
# Out:
# Dang Tri Dung
# Trinh Duc Cuong

# %%
import openpyxl
url = "Book1.xlsx"
wb = openpyxl.load_workbook(url)
sheet = wb.active
row = sheet.max_row
for i in range(1, row + 1):
  cell = sheet.cell(row = i, column = 1)
  print(cell.value)
# Out:
# Dang Tri Dung
# Ulsan

# %%
import openpyxl
url = "Book1.xlsx"
wb = openpyxl.load_workbook(url)
sheet = wb.active
col = sheet.max_column
for i in range(1, col + 1):
  cell = sheet.cell(row = 2, column = i)
  print(cell.value, end = " ")
# Out:
# Ulsan Genovoa

# %%
import numpy as np
vector_row = np.array([1, 2, 3])
vector_column = np.array([[4], [5], [6]])

vector_row
vector_column
# Out:
# array([[4],
#        [5],
#        [6]])

# %%
import numpy as np
matrix = np.array([[1, 2],
                   [3, 4],
                   [5, 6]])
matrix
# Out:
# array([[1, 2],
#        [3, 4],
#        [5, 6]])

# %%
nhan_ba = lambda a: a*3
nhan_ba(10)
# Out:
# 30

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.arange(6)
y = x+1
plt.plot(x, y, "o--")
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
plt.plot(x, y, "o--", color = "yellow")
plt.plot(x, -y, "o-", color = "red")
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
plt.plot(x, y, "o--", color = "yellow")
plt.plot(x, -y, "o-", color = "red")
plt.title("y=x và y=-x")
plt.xlabel("x")
plt.ylabel("y")
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
plt.plot(x, y, "o--", color = "yellow")
plt.plot(x, -y, "o-", color = "red")
plt.title("y=x và y=-x")
plt.xlabel("x")
plt.ylabel("y")
plt.axis("off")
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
x = np.linspace(0, 15, 16)
y = x
plt.plot(x, y, "o--")
plt.axis("off")
plt.show()

# %%
N = 16
x = np.linspace(0, 15, 16)
y = np.logspace(0.1, 2, 16)
plt.plot(x, y, "--o")
plt.show()

# %%
x = [4, 5, 3, 1, 6, 7]
plt.plot(x)
plt.show()

# %%
x = np.arange(26)
plt.plot(x)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
#x = y^3 + 1
x = np.arange(25)
plt.plot(x, x**3 + 1)
plt.show()

# %%
x = np.arange(7)
plt.plot(x, -x**2, "-")
plt.plot(x, -x**3, "--")
plt.plot(x, -2*x, "-o")
plt.plot(x, -2**x, ":")
plt.show()

# %%
x = np.arange(7)
plt.plot(x, -x**2, x, -x**3, x, -2*x, x, -2**x)
plt.show()

# %%
x = np.arange(7)
plt.plot(x, -x**2, x, -x**3, x, -2*x, x, -2**x)
plt.grid(True)
plt.savefig("test.png")
plt.show()

# %%
x = np.arange(100)
plt.subplots_adjust(wspace = 0.3, hspace = 0.3)
plt.subplot(2, 2, 1)
plt.plot(x, -x**2, color="green")
plt.subplot(2, 2, 2)
plt.plot(x, -x**3, color="red")
plt.subplot(2, 2, 3)
plt.plot(x, -2*x, color="black")
plt.subplot(2, 2, 4)
plt.plot(x, -2**x, color="orange")
plt.show()

# %%
plt.axis([0,100,0,10])
plt.scatter(40,5, s=1000, color="blue", alpha=1)
#alpha: độ đậm (giá trị: 0 đến 1)
plt.scatter(60,5, s=1000, color="black", alpha=.5)
plt.scatter(80,5, s=1000, color="green", alpha=.1)
plt.show()

# %%
#plt.plot([xA,xB], [yA,yB], linewidth = 5, color="r")
plt.plot([0,10], [0,10], linewidth = 5, color="r")
plt.text(4,6,"ABC")
plt.show()

# %%
#plt.plot([xA,xB], [yA,yB], linewidth = 5, color="r")
plt.plot([0,1,2,3,4], [0,1,4,9,16], linewidth = 5, color="r")
plt.text(4,6,"ABC")
plt.show()

# %%
plt.arrow(0.5, 1, 0, -0.5, head_length=1, head_width = 2, color="green")
plt.show()

# %%
x = np.arange(4)
y = np.random.rand(4)
plt.bar(x,y)
plt.show()

# %%
y = np.random.rand(3,4)
plt.bar(x+0, y[0], color="blue", width=0.25)
plt.bar(x+0.25, y[1], color="green", width=0.25)
plt.bar(x+0.5, y[2], color="red", width=0.25)
plt.show()

# %%
a = np.arange(4)
y = np.random.rand(4)
plt.barh(x,y)
plt.show()

# %%
y = np.random.rand(3,4)
plt.barh(x+0, y[0], color="blue", height=0.25)
plt.barh(x+0.25, y[1], color="green", height=0.25)
plt.barh(x+0.5, y[2], color="red", height=0.25)
plt.show()

# %%
N = 1000
x = np.random.rand(N)
y = np.random.rand(N)
colors = np.random.rand(N)
size = 20
plt.scatter(x, y, s=size, c= colors, alpha=1)
plt.show()
